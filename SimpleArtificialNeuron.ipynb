# %%
import numpy as np
from google.colab import files


x=np.loadtxt("entradas.txt", delimiter=" ")
print(x)



w=[-3, -4]

#soma de x*w
for i in range (0, len(x)):
  u=sum(x[i]*w)
  if u >=0:
    y=1
  else:
    y=0
  print(f'potencia de ativação = {u}')
  print(f"saida = {y}")
